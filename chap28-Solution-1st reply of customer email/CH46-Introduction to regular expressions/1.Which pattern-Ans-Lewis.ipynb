# %% [markdown]
# # 練習
# Which pattern?
# Which of the following Regex patterns results in the following text?

# %% [raw]
# >>> my_string = "Let's write RegEx!"
# >>> re.findall(PATTERN, my_string)
# ['Let', 's', 'write', 'RegEx']

# %%
import re
my_string = "Let's write RegEx!"
re.findall(r"\w+", my_string)
# Out:
# ['Let', 's', 'write', 'RegEx']

# %% [markdown]
# In the IPython Shell, try replacing PATTERN with one of the below options and observe the resulting output. The re module has been pre-imported for you and my_string is available in your namespace.

# %%
Possible Answers
( ) PATTERN = r"\s+"
(*) PATTERN = r"\w+"
( ) PATTERN = r"[a-z]"
( ) PATTERN = r"\w"

# %%
# 準備事項
import re
my_string = "Let's write RegEx2022!"
re.findall( '\w+' , my_string)
# Out:
# ['Let', 's', 'write', 'RegEx2022']

# %%
# 預計結果
# ['Let', 's', 'write', 'RegEx']
# Out:
# ['Let', 's', 'write', 'RegEx']
