# %% [markdown]
# # Word2vec Tomas Mikolov, et al. at Google in 2013

# %%
# 安裝套件
# !pip install gensim

# %%
from gensim.models import Word2Vec
Word2Vec?

# %%
from gensim.models import Word2Vec
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
            ['this', 'is', 'the', 'second', 'sentence'],
            ['yet', 'another', 'sentence'],
            ['one', 'more', 'sentence'],
            ['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1, size=100) # 100 特徵數量100個 (二階張量)
#print(dir(model.wv))
# # summarize the loaded model
print(list(model.wv.vocab))   # 輸出該內容的單字數量(剛好是 i 上下)
print(model.wv.vectors.shape) # 輸出該單字轉換成向量之後的維度(14個單字(上下)每一個單字 100 特徵(左右))
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# ['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec', 'second', 'yet', 'another', 'one', 'more', 'and', 'final']
# (14, 100)

# %%
# 根據單字抓取對應特徵值 
model.wv['this']
# Out:
# array([ 5.98420622e-04,  3.19071743e-03, -1.41294149e-03, -2.03819573e-03,
#        -1.78830946e-04, -2.34480109e-03,  1.13543740e-03,  4.12982097e-03,
#        -7.61154748e-04, -8.38595501e-04, -2.91099469e-03,  2.05922872e-04,
#        -3.52759217e-03,  4.79574176e-03, -2.05639936e-03, -6.71612739e-04,
#        -3.64235416e-03,  3.73432599e-03, -7.72520667e-04,  4.45078081e-03,
#         3.16659454e-03, -2.24670657e-04, -3.52214137e-03,  1.74115668e-03,
#        -6.20712701e-04, -4.64695459e-03,  9.65211715e-04,  7.09467742e-04,
#        -3.74967465e-03, -2.33664690e-03,  4.68309736e-03, -1.38993398e-03,
#        -3.86502105e-03,  2.41792947e-03,  1.25714182e-03, -4.25323145e-03,
#        -7.24303245e-04, -3.47766140e-03,  3.68419709e-03, -1.40532735e-03,
#        -1.76916213e-03, -2.29120706e-04, -4.46810201e-03,  1.84961199e-03,
#        -1.99486082e-03,  3.20333824e-03,  4.67149401e-03, -4.67408914e-03,
# ...

# %%
# this
model.wv.vectors.shape
# Out:
# (14, 100)

# %%
from gensim.models import Word2Vec
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
            ['this', 'is', 'the', 'second', 'sentence'],
            ['yet', 'another', 'sentence'],
            ['one', 'more', 'sentence'],
            ['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# summarize the loaded model
print(model, '\n')
# summarize vocabulary
words = list(model.wv.vocab)
print('words list\n', words, '\n')
# access vector for one word
print('vector of sentence 該單字\n', model.wv['sentence'], '\n')
# save model
model.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
print('new_model', new_model)
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Word2Vec(vocab=14, size=100, alpha=0.025)
#
# words list
#  ['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec', 'second', 'yet', 'another', 'one', 'more', 'and', 'final']
#
# vector of sentence 該單字
#  [-3.2547814e-05 -2.3627270e-03  2.8110987e-03  9.2274096e-04
#  -4.0778573e-04  1.8918636e-06 -1.0411977e-03  3.9066086e-03
#  -2.2633327e-03  9.8390621e-04  3.2309550e-03  2.0337131e-04
#   1.8472252e-04  3.0073910e-03  3.8229742e-03  1.6357300e-03
#   2.2090843e-04  9.3355519e-04 -1.3270699e-04 -3.2337073e-03
#   1.5860678e-03  1.2443954e-03 -3.3538463e-03 -4.6984097e-03
#   7.7678979e-04  4.0058196e-03  8.5203792e-04  1.4723777e-03
#   4.4330903e-03 -2.5876439e-03  2.7876880e-03  2.9898360e-03
#   5.6555192e-04  3.6952200e-03  2.5956071e-04  2.1619389e-03
#  -1.6289554e-03 -2.4096924e-03  1.4427642e-03 -1.6350759e-03
# ...

# %%
#print(dir(model.wv))
model.wv.vocab
#model.wv.vectors
# Out:
# {'this': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffa90>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f6c348ff890>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffcd0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffbd0>,
#  'sentence': <gensim.models.keyedvectors.Vocab at 0x7f6c348ff2d0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffb90>,
#  'word2vec': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffc10>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7f6c348ff050>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffa50>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffc50>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f6c348fff10>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f6c348ff9d0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f6c348ffd10>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7f6c348ff0d0>}

# %%
model.wv[['this', 'is']].shape
# Out:
# (2, 100)

# %%
# 將數個單字原始特徵數量為100的狀況下，透過特徵向量 特徵值 降低到僅有兩個維度的特徵
from sklearn.decomposition import PCA
pca = PCA(n_components = 2 )
src = model.wv[['this', 'is', 'and']]
new = pca.fit_transform(src)
new.shape
# Out:
# (3, 2)

# %%
# %matplotlib inline
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
            ['this', 'is', 'the', 'second', 'sentence'],
            ['yet', 'another', 'sentence'],
            ['one', 'more', 'sentence'],
            ['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
words = list(model.wv.vocab) # 列出所有的單字


# fit a 2d PCA model to the vectors
X = model.wv[words]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# create a scatter plot of the projection
plt.figure(figsize=(18,6))
plt.scatter(result[:, 0], result[:, 1], marker='^', color ='red')

for i, word in enumerate(words):
    plt.annotate(word, xy=(result[i, 0], result[i, 1]), fontsize=15)
plt.show()
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
# Similarity 利用 word2vec 向量找出同義字 pc = workstation = server = computer
model.wv.similar_by_word('more')
# Out:
# [('sentence', 0.1622963845729828),
#  ('final', 0.16198748350143433),
#  ('word2vec', 0.07818976789712906),
#  ('second', 0.05456963926553726),
#  ('is', 0.04144814983010292),
#  ('another', 0.01548905298113823),
#  ('yet', 0.002230647951364517),
#  ('and', -0.012928936630487442),
#  ('one', -0.01695740595459938),
#  ('for', -0.06502298265695572)]

# %%
model.wv.similarity('yet', 'for')
# Out:
# 0.057328638
