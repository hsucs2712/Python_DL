# %%
import requests as r
import json
import pandas as pd
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
bike = pd.DataFrame(json.loads(r.get(url).text ))
bike[:3]
# Out:
#          sno                     sna  tot  sbi sarea                 mday  \
# 0  500101001      YouBike2.0_捷運科技大樓站   28    0   大安區  2022-11-27 11:35:38
# 1  500101002  YouBike2.0_復興南路二段273號前   21    2   大安區  2022-11-27 11:32:12
# 2  500101003    YouBike2.0_國北教大實小東側門   16    4   大安區  2022-11-27 11:30:30
#
#         lat        lng            ar     sareaen  \
# 0  25.02605  121.54360   復興南路二段235號前  Daan Dist.
# 1  25.02565  121.54357  復興南路二段273號西側  Daan Dist.
# 2  25.02429  121.54124   和平東路二段96巷7號  Daan Dist.
#
#                                                snaen  \
# 0               YouBike2.0_MRT Technology Bldg. Sta.
# 1           YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2  YouBike2.0_NTUE Experiment Elementary School (...
#
#                                    aren  bemp act        srcUpdateTime  \
# 0         No.235， Sec. 2， Fuxing S. Rd.    28   1  2022-11-27 11:36:12
# 1  No.273， Sec. 2， Fuxing S. Rd. (West)    19   1  2022-11-27 11:36:12
# 2   No. 7， Ln. 96， Sec. 2， Heping E. Rd    12   1  2022-11-27 11:36:12
#
#             updateTime             infoTime    infoDate
# 0  2022-11-27 11:36:25  2022-11-27 11:35:38  2022-11-27
# 1  2022-11-27 11:36:25  2022-11-27 11:32:12  2022-11-27
# 2  2022-11-27 11:36:25  2022-11-27 11:30:30  2022-11-27

# %%
import requests as r
import json
import pandas as pd
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
data =r.get(url) 
print(data.text[:100])
pd.DataFrame(json.loads(data.text))

# %%
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
import pandas as pd
bike = pd.read_json(url)

# %%
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
import pandas as pd
pd.read_json(url)

# %%
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
import pandas as pd
print(pd.read_json(url)[:1])
