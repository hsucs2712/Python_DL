# %% [markdown]
# # 練習
# Aliasing, rotating and rescaling
# Let's look at the impact of aliasing on images.
#
# Remember that aliasing is an effect that causes different signals, in this case pixels, to become indistinguishable or distorted.
#
# You'll make this cat image upright by rotating it 90 degrees and then rescaling it two times. Once with the anti aliasing filter applied before rescaling and a second time without it, so you can compare them.
#
# Little cute cat
# Iamge preloaded as image_cat.
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
# 準備作業
import matplotlib.pyplot as plt
def show_image(image, title='Image', cmap_type='gray', interpolation=None):
    plt.imshow(image, cmap=cmap_type)    
    plt.title(title)
    #plt.axis('off')
    plt.show()
    
def plot_comparision(original, filtered, title_filtered):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(32,8), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(title_filtered)
    ax2.axis('off')

image_cat = plt.imread('image_cat.jpg')
image_cat.shape
# Out:
# (612, 640, 3)

# %%
from skimage.transform import rotate, rescale, resize
# rescale?

# %%
# 提示
# Import the module and the rotating and rescaling functions

from skimage.transform import rotate, rescale

# Rotate the image 90 degrees clockwise 
rotated_cat_image = rotate(image_cat, -90)

# Rescale the cat_image to be 4 times smaller and apply the anti aliasing filter. 
# Set whether or not the image should be treated as multichannel (colored).

# Rescale with anti aliasing
rescaled_with_aa = rescale(rotated_cat_image, 1/4, anti_aliasing=True, multichannel=True)

# Rescale the rotated_cat_image to be 4 times smaller without applying an anti aliasing filter.
rescaled_without_aa = rescale(rotated_cat_image, 1/4, anti_aliasing=False, multichannel=True)

# Show the resulting images
show_image(rescaled_with_aa, "Transformed with anti aliasing")
show_image(rescaled_without_aa, "Transformed without anti aliasing")
print(rescaled_with_aa.shape)
# Out:
# (153, 160, 3)

# %%
# 預期結果

original, hist = plt.imread('Transformed with anti aliasing.png'), \
                     plt.imread('Transformed without anti aliasing.png')

plot_comparision(original, hist, 'Histogram of Aliasing')

# %% [markdown]
# # 練習
# Enlarging images
# Have you ever tried resizing an image to make it larger? This usually results in loss of quality, with the enlarged image looking blurry.
#
# The good news is that the algorithm used by scikit-image works very well for enlarging images up to a certain point.
#
# In this exercise you'll enlarge an image four times!!
#
# You'll do this by rescaling the image of a rocket, that will be loaded from the data module.
#
# Rocket
# ![image.png](attachment:image.png)

# %%
# 提示
# Import the module and function needed to enlarge images, you'll do this by rescaling.
# Import the data module.
# Load the rocket() image from data.
# Enlarge the rocket_image so it is 4 times bigger, with the anti aliasing filter applied.

# %%
rescale?

# %%
# Import the module and function to enlarge images
from skimage.transform import rescale

# Import the data module
from skimage import data

# Load the image from data
rocket_image = data.rocket()

# Enlarge the image so it is 4 times bigger
enlarged_rocket_image = rescale(rocket_image, 4, anti_aliasing=True, multichannel=True)

# Show original and resulting image
show_image(rocket_image)
show_image(enlarged_rocket_image, "4 times enlarged image")

# %%
# 預期結果
original, hist = plt.imread('original rocket.png'), \
                     plt.imread('4 times enlarged image.png')

plot_comparision(original, hist, 'Histogram of Rescale')

# %% [markdown]
# # 練習
# Proportionally resizing
# We want to downscale the images of a veterinary blog website so all of these have the same compressed size.
#
# It's important that you do this proportionally, meaning that these are not distorted.
#
# First, you'll try it out for one image so you know what code to test later in the rest of pictures.
#
#
# The image preloaded as dogs_banner.
# Remember that by looking at the shape of the image, you can know its width and height.
# ![image.png](attachment:image.png)

# %%
# 準備事項
def plot_comparision(original, filtered, title_filtered):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(32,8), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('on')
    
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(title_filtered)
    ax2.axis('on')


dogs_banner = plt.imread('dogs_banner.jpg')
print(dogs_banner.shape)
plt.imshow(dogs_banner)
plt.show()
# Out:
# (423, 640, 3)

# %%
# Import the module and function
from skimage.transform import resize

# Set proportional height so its half its size
height = int(dogs_banner.shape[0] / 2)
width = int(dogs_banner.shape[1] / 2)

# Resize using the calculated proportional height and width
image_resized = resize(dogs_banner, (height, width),
                       anti_aliasing=True)

# Show the original and rotated image
show_image(dogs_banner, 'Original')
show_image(image_resized, 'Resized image')

# %%
# 預期結果
original, hist = plt.imread('original.png'), \
                     plt.imread('resize image.png')

plot_comparision(original, hist, 'Histogram of Resize')
