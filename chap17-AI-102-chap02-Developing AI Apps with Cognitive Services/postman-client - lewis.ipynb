# %%
import requests

url = "https://azml0608.cognitiveservices.azure.com/text/analytics/v3.1/languages"

payload = "{\r\n  \"documents\": [\r\n    {\r\n      \"id\": 1,\r\n      \"text\": \"How are you?\"\r\n    }\r\n  ]\r\n}\r\n"
headers = {
    'content-type': "application/json",
    'ocp-apim-subscription-key': "d294986eff75428898f84f7d6b80f694",
    'cache-control': "no-cache",
    'postman-token': "3aa4057d-8f59-0b55-d255-637ba2ae372b"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"documents":[{"id":"1","detectedLanguage":{"name":"English","iso6391Name":"en","confidenceScore":1.0},"warnings":[]}],"errors":[],"modelVersion":"2021-11-20"}

# %%
import http.client

conn = http.client.HTTPSConnection("azml0608.cognitiveservices.azure.com")

payload = "{\r\n  \"documents\": [\r\n    {\r\n      \"id\": 1,\r\n      \"text\": \"How are you?\"\r\n    }\r\n  ]\r\n}\r\n"

headers = {
    'content-type': "application/json",
    'ocp-apim-subscription-key': "d294986eff75428898f84f7d6b80f694",
    'cache-control': "no-cache",
    'postman-token': "a12b6075-8c1a-9b3d-ac07-05baace28a41"
    }

conn.request("POST", "/text/analytics/v3.1/languages", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"documents":[{"id":"1","detectedLanguage":{"name":"English","iso6391Name":"en","confidenceScore":1.0},"warnings":[]}],"errors":[],"modelVersion":"2021-11-20"}
