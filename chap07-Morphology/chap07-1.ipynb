# %%
# --外型 型態 Morphology 先轉為 Gray -- 才可以處理
# from skimage import morphology
# morphology.binary_erosion(image, selem)

# morphology.binary_dilation(image)

# %%
from skimage import morphology
print(dir(morphology))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_convex_hull', '_deprecated', '_extrema_cy', '_flood_fill', '_flood_fill_cy', '_max_tree', '_skeletonize', '_skeletonize_3d_cy', '_skeletonize_cy', '_util', 'area_closing', 'area_opening', 'ball', 'binary', 'binary_closing', 'binary_dilation', 'binary_erosion', 'binary_opening', 'black_tophat', 'closing', 'convex_hull', 'convex_hull_image', 'convex_hull_object', 'cube', 'diameter_closing', 'diameter_opening', 'diamond', 'dilation', 'disk', 'erosion', 'extrema', 'flood', 'flood_fill', 'grey', 'greyreconstruct', 'h_maxima', 'h_minima', 'label', 'local_maxima', 'local_minima', 'max_tree', 'max_tree_local_maxima', 'medial_axis', 'misc', 'octagon', 'octahedron', 'opening', 'reconstruction', 'rectangle', 'remove_small_holes', 'remove_small_objects', 'selem', 'skeletonize', 'skeletonize_3d', 'square', 'star', 'thin', 'watershed', 'white_tophat']

# %%
a = %pwd
print(a)
# Out:
# /content

# %%
from skimage import color, io
img = io.imread('./world_image_binary.jpg', as_gray=True)
io.imshow(img, cmap='gray')
img.shape, img.dtype
# Out:
# ((327, 640), dtype('uint8'))

# %%
# !pip list

# %%
from skimage import morphology
scan = morphology.rectangle(4, 8)

# %%
morphology.binary_erosion?

# %%
import matplotlib.pyplot as plt
andy_erosion = morphology.binary_erosion(img, selem = scan)
plt.imshow(andy_erosion, cmap = 'gray')
plt.show()
andy_erosion.dtype
# Out:
# dtype('bool')
