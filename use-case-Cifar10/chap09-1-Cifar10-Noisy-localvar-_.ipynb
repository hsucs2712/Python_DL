# %%
# https://chatbotslife.com/cnn-image-classification-using-cifar-10-dataset-on-google-colab-tpu-750da8cd8510
# https://github.com/santanu13/CIFAR_10_Classification_TPU/blob/master/CIFAR_10_CLASSIFICATION_TPU.ipynb

# %%
#Import libraries
import os
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

#Download dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
print(x_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3)

# %%
#此處將數據轉換成灰階樣本
from skimage import color
from skimage import exposure
from skimage.transform import rescale
from skimage.util import random_noise
import matplotlib.pyplot as plt
modes = ['gaussian', 'localvar', 'poisson', 'salt', 'pepper', 's&p', 'speckle' ]

def imagepro(img, display):
    
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('Original')
        plt.imshow(img)
        plt.axis('off')
        plt.show()

    sample = random_noise(img, mode= modes[1])
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('random_noise')
        plt.imshow(sample)
        plt.axis('off')
        plt.show()

    
    return sample
# 驗證
x = imagepro(img = x_train[1], display = True)

# %%
# 產生標籤
name2num = {'airplane' : 0,
            'automobile' : 1,
            'bird' : 2,
            'cat' : 3,
            'deer' : 4,
            'dog' : 5,
            'frog' : 6,
            'horse' : 7,
            'ship' : 8,
            'truck' : 9}
num2name = dict([(v,k) for (k,v) in name2num.items()])
num2name
# Out:
# {0: 'airplane',
#  1: 'automobile',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %%
# %%time
###########################################
#所有影像處理都在這裡
# source = x_train, x_test
# target = x_train_skimage, x_test_skiage
###########################################
x_train_skimage = np.array( [ imagepro(img = x, display = False) for x in x_train]  )
x_test_skimage = np.array(  [ imagepro(img = x, display = False) for x in x_test]  )
# Out:
# CPU times: user 26.2 s, sys: 1.9 s, total: 28.1 s
# Wall time: 30.5 s

# %%
# 請幫忙顯示十張truck 原來數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 請幫忙顯示十張truck 處理後數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train_skimage[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 檢視是否需要將數據進行處理 /255.0
# 更換數據
x_train_skimage[0].min(), x_train_skimage[0].max()
# Out:
# (0.0, 1.0)

# %%
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 
x_Test_norm = x_test_skimage.reshape(x_test_skimage.shape[0], 
                                     x_test_skimage.shape[1]*x_test_skimage.shape[2]*3).astype('float32') # /255.0
del x_test_skimage
x_Train_norm = x_train_skimage.reshape(x_train_skimage.shape[0], 
                                       x_train_skimage.shape[1]*x_train_skimage.shape[2]*3).astype('float32')   #/255.0
del x_train_skimage

# %%
# y_TrainOneHot = np_utils.to_categorical(y_train) 
# y_TestOneHot = np_utils.to_categorical(y_test) 

# # 將 training 的 input 資料轉為2維
# x_train = x_train_skimage #<--------------preprocessed by skimage
# x_test  = x_test_skimage  #<--------------preprocessed by skimage

# X_train_2D = x_train.reshape(x_train.shape[0], 64*64*3).astype('float32')  
# X_test_2D = x_test.reshape(x_test.shape[0], 64*64*3).astype('float32')    
# x_Train_norm = X_train_2D /255.0  #<------
# x_Test_norm = X_test_2D   /255.0  #<------

# %%
# 建置model 
# 導入函式庫
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=x_Train_norm.shape[1], kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=30, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/30
# 50/50 - 3s - loss: 2.0673 - accuracy: 0.2548 - val_loss: 1.9188 - val_accuracy: 0.3248 - 3s/epoch - 54ms/step
# Epoch 2/30
# 50/50 - 2s - loss: 1.8593 - accuracy: 0.3498 - val_loss: 1.8414 - val_accuracy: 0.3525 - 2s/epoch - 37ms/step
# Epoch 3/30
# 50/50 - 2s - loss: 1.7860 - accuracy: 0.3744 - val_loss: 1.7932 - val_accuracy: 0.3667 - 2s/epoch - 37ms/step
# Epoch 4/30
# 50/50 - 2s - loss: 1.7246 - accuracy: 0.3969 - val_loss: 1.7407 - val_accuracy: 0.3918 - 2s/epoch - 37ms/step
# Epoch 5/30
# 50/50 - 2s - loss: 1.6792 - accuracy: 0.4132 - val_loss: 1.7061 - val_accuracy: 0.4006 - 2s/epoch - 37ms/step
# Epoch 6/30
# 50/50 - 2s - loss: 1.6570 - accuracy: 0.4186 - val_loss: 1.6832 - val_accuracy: 0.4125 - 2s/epoch - 37ms/step
# Epoch 7/30
# 50/50 - 2s - loss: 1.6186 - accuracy: 0.4347 - val_loss: 1.6695 - val_accuracy: 0.4134 - 2s/epoch - 37ms/step
# Epoch 8/30
# 50/50 - 2s - loss: 1.5947 - accuracy: 0.4439 - val_loss: 1.6474 - val_accuracy: 0.4230 - 2s/epoch - 37ms/step
# Epoch 9/30
# 50/50 - 2s - loss: 1.5706 - accuracy: 0.4503 - val_loss: 1.6465 - val_accuracy: 0.4194 - 2s/epoch - 37ms/step
# Epoch 10/30
# 50/50 - 2s - loss: 1.5532 - accuracy: 0.4564 - val_loss: 1.6202 - val_accuracy: 0.4308 - 2s/epoch - 37ms/step
# Epoch 11/30
# 50/50 - 2s - loss: 1.5368 - accuracy: 0.4618 - val_loss: 1.6064 - val_accuracy: 0.4345 - 2s/epoch - 37ms/step
# Epoch 12/30
# 50/50 - 2s - loss: 1.5176 - accuracy: 0.4681 - val_loss: 1.6063 - val_accuracy: 0.4376 - 2s/epoch - 37ms/step
# Epoch 13/30
# 50/50 - 2s - loss: 1.5026 - accuracy: 0.4748 - val_loss: 1.5830 - val_accuracy: 0.4428 - 2s/epoch - 38ms/step
# Epoch 14/30
# 50/50 - 2s - loss: 1.4830 - accuracy: 0.4811 - val_loss: 1.5778 - val_accuracy: 0.4459 - 2s/epoch - 37ms/step
# Epoch 15/30
# 50/50 - 2s - loss: 1.4648 - accuracy: 0.4884 - val_loss: 1.5653 - val_accuracy: 0.4535 - 2s/epoch - 37ms/step
# Epoch 16/30
# 50/50 - 2s - loss: 1.4533 - accuracy: 0.4910 - val_loss: 1.5875 - val_accuracy: 0.4389 - 2s/epoch - 37ms/step
# Epoch 17/30
# 50/50 - 2s - loss: 1.4488 - accuracy: 0.4928 - val_loss: 1.5599 - val_accuracy: 0.4557 - 2s/epoch - 37ms/step
# Epoch 18/30
# 50/50 - 2s - loss: 1.4293 - accuracy: 0.4999 - val_loss: 1.5471 - val_accuracy: 0.4553 - 2s/epoch - 37ms/step
# Epoch 19/30
# 50/50 - 2s - loss: 1.4212 - accuracy: 0.5019 - val_loss: 1.5563 - val_accuracy: 0.4501 - 2s/epoch - 37ms/step
# Epoch 20/30
# 50/50 - 2s - loss: 1.4029 - accuracy: 0.5102 - val_loss: 1.5421 - val_accuracy: 0.4570 - 2s/epoch - 38ms/step
# Epoch 21/30
# 50/50 - 2s - loss: 1.3958 - accuracy: 0.5112 - val_loss: 1.5485 - val_accuracy: 0.4524 - 2s/epoch - 46ms/step
# Epoch 22/30
# 50/50 - 2s - loss: 1.3820 - accuracy: 0.5199 - val_loss: 1.5467 - val_accuracy: 0.4529 - 2s/epoch - 46ms/step
# Epoch 23/30
# 50/50 - 2s - loss: 1.3684 - accuracy: 0.5238 - val_loss: 1.5488 - val_accuracy: 0.4559 - 2s/epoch - 37ms/step
# Epoch 24/30
# 50/50 - 2s - loss: 1.3671 - accuracy: 0.5221 - val_loss: 1.5270 - val_accuracy: 0.4592 - 2s/epoch - 37ms/step
# Epoch 25/30
# 50/50 - 2s - loss: 1.3585 - accuracy: 0.5249 - val_loss: 1.5287 - val_accuracy: 0.4604 - 2s/epoch - 37ms/step
# Epoch 26/30
# 50/50 - 2s - loss: 1.3421 - accuracy: 0.5310 - val_loss: 1.5244 - val_accuracy: 0.4595 - 2s/epoch - 37ms/step
# Epoch 27/30
# 50/50 - 2s - loss: 1.3326 - accuracy: 0.5342 - val_loss: 1.5337 - val_accuracy: 0.4569 - 2s/epoch - 37ms/step
# Epoch 28/30
# 50/50 - 2s - loss: 1.3249 - accuracy: 0.5362 - val_loss: 1.5218 - val_accuracy: 0.4620 - 2s/epoch - 38ms/step
# Epoch 29/30
# 50/50 - 2s - loss: 1.3157 - accuracy: 0.5404 - val_loss: 1.5173 - val_accuracy: 0.4673 - 2s/epoch - 38ms/step
# Epoch 30/30
# 50/50 - 2s - loss: 1.3103 - accuracy: 0.5422 - val_loss: 1.5213 - val_accuracy: 0.4654 - 2s/epoch - 37ms/step

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4967 - accuracy: 0.4731
#
# 	[Info] Accuracy of testing data = 47.3%

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Train_norm, y_TrainOneHot)  
print()  
print("\t[Info] Accuracy of training data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3349 - accuracy: 0.5351
#
# 	[Info] Accuracy of training data = 53.5%

# %%
# %matplotlib inline
# accuracy chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
# %matplotlib inline
# loss chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
