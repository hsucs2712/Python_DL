# %%
# https://chatbotslife.com/cnn-image-classification-using-cifar-10-dataset-on-google-colab-tpu-750da8cd8510
# https://github.com/santanu13/CIFAR_10_Classification_TPU/blob/master/CIFAR_10_CLASSIFICATION_TPU.ipynb

# %%
#Import libraries
import os
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

#Download dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
#此處將數據轉換成灰階樣本
from skimage import color
from skimage import exposure
from skimage.transform import rescale
from skimage.util import random_noise
import matplotlib.pyplot as plt
modes = ['gaussian', 'localvar', 'poisson', 'salt', 'pepper', 's&p', 'speckle' ]

def imagepro(img, display):
    
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('Original')
        plt.imshow(img)
        plt.axis('off')
        plt.show()

    sample = random_noise(img, mode= modes[2])
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('random_noise')
        plt.imshow(sample)
        plt.axis('off')
        plt.show()

    
    return sample
# 驗證
x = imagepro(img = x_train[1], display = True)

# %%
# 產生標籤
name2num = {'airplane' : 0,
            'automobile' : 1,
            'bird' : 2,
            'cat' : 3,
            'deer' : 4,
            'dog' : 5,
            'frog' : 6,
            'horse' : 7,
            'ship' : 8,
            'truck' : 9}
num2name = dict([(v,k) for (k,v) in name2num.items()])
num2name
# Out:
# {0: 'airplane',
#  1: 'automobile',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %%
# %%time
###########################################
#所有影像處理都在這裡
# source = x_train, x_test
# target = x_train_skimage, x_test_skiage
###########################################
x_train_skimage = np.array( [ imagepro(img = x, display = False) for x in x_train]  )
x_test_skimage = np.array(  [ imagepro(img = x, display = False) for x in x_test]  )
# Out:
# CPU times: user 53.4 s, sys: 552 ms, total: 54 s
# Wall time: 55 s

# %%
# 請幫忙顯示十張truck 原來數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 請幫忙顯示十張truck 處理後數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train_skimage[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 檢視是否需要將數據進行處理 /255.0
# 更換數據
x_train_skimage[0].min(), x_train_skimage[0].max()
# Out:
# (0.0, 1.0)

# %%
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 
x_Test_norm = x_test_skimage.reshape(x_test_skimage.shape[0], 
                                     x_test_skimage.shape[1]*x_test_skimage.shape[2]*3).astype('float32') # /255.0
del x_test_skimage
x_Train_norm = x_train_skimage.reshape(x_train_skimage.shape[0], 
                                       x_train_skimage.shape[1]*x_train_skimage.shape[2]*3).astype('float32')   #/255.0
del x_train_skimage

# %%
# y_TrainOneHot = np_utils.to_categorical(y_train) 
# y_TestOneHot = np_utils.to_categorical(y_test) 

# # 將 training 的 input 資料轉為2維
# x_train = x_train_skimage #<--------------preprocessed by skimage
# x_test  = x_test_skimage  #<--------------preprocessed by skimage

# X_train_2D = x_train.reshape(x_train.shape[0], 64*64*3).astype('float32')  
# X_test_2D = x_test.reshape(x_test.shape[0], 64*64*3).astype('float32')    
# x_Train_norm = X_train_2D /255.0  #<------
# x_Test_norm = X_test_2D   /255.0  #<------

# %%
# 建置model 
# 導入函式庫
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=x_Train_norm.shape[1], kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 128)               393344
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=30, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/30
# 50/50 - 2s - loss: 1.9885 - accuracy: 0.2807 - val_loss: 1.8714 - val_accuracy: 0.3384 - 2s/epoch - 47ms/step
# Epoch 2/30
# 50/50 - 2s - loss: 1.8102 - accuracy: 0.3604 - val_loss: 1.7961 - val_accuracy: 0.3604 - 2s/epoch - 37ms/step
# Epoch 3/30
# 50/50 - 2s - loss: 1.7423 - accuracy: 0.3875 - val_loss: 1.7417 - val_accuracy: 0.3871 - 2s/epoch - 37ms/step
# Epoch 4/30
# 50/50 - 2s - loss: 1.6911 - accuracy: 0.4020 - val_loss: 1.7136 - val_accuracy: 0.4002 - 2s/epoch - 36ms/step
# Epoch 5/30
# 50/50 - 2s - loss: 1.6544 - accuracy: 0.4198 - val_loss: 1.6759 - val_accuracy: 0.4130 - 2s/epoch - 37ms/step
# Epoch 6/30
# 50/50 - 2s - loss: 1.6219 - accuracy: 0.4323 - val_loss: 1.6584 - val_accuracy: 0.4171 - 2s/epoch - 36ms/step
# Epoch 7/30
# 50/50 - 2s - loss: 1.6013 - accuracy: 0.4375 - val_loss: 1.6384 - val_accuracy: 0.4260 - 2s/epoch - 37ms/step
# Epoch 8/30
# 50/50 - 2s - loss: 1.5703 - accuracy: 0.4516 - val_loss: 1.6064 - val_accuracy: 0.4363 - 2s/epoch - 37ms/step
# Epoch 9/30
# 50/50 - 2s - loss: 1.5503 - accuracy: 0.4585 - val_loss: 1.6074 - val_accuracy: 0.4360 - 2s/epoch - 37ms/step
# Epoch 10/30
# 50/50 - 2s - loss: 1.5372 - accuracy: 0.4600 - val_loss: 1.5911 - val_accuracy: 0.4451 - 2s/epoch - 37ms/step
# Epoch 11/30
# 50/50 - 2s - loss: 1.5165 - accuracy: 0.4671 - val_loss: 1.5926 - val_accuracy: 0.4410 - 2s/epoch - 36ms/step
# Epoch 12/30
# 50/50 - 2s - loss: 1.5010 - accuracy: 0.4733 - val_loss: 1.5585 - val_accuracy: 0.4527 - 2s/epoch - 37ms/step
# Epoch 13/30
# 50/50 - 2s - loss: 1.4872 - accuracy: 0.4763 - val_loss: 1.5662 - val_accuracy: 0.4463 - 2s/epoch - 36ms/step
# Epoch 14/30
# 50/50 - 2s - loss: 1.4670 - accuracy: 0.4857 - val_loss: 1.5611 - val_accuracy: 0.4536 - 2s/epoch - 36ms/step
# Epoch 15/30
# 50/50 - 2s - loss: 1.4568 - accuracy: 0.4890 - val_loss: 1.5493 - val_accuracy: 0.4541 - 2s/epoch - 36ms/step
# Epoch 16/30
# 50/50 - 2s - loss: 1.4564 - accuracy: 0.4874 - val_loss: 1.5490 - val_accuracy: 0.4567 - 2s/epoch - 36ms/step
# Epoch 17/30
# 50/50 - 2s - loss: 1.4433 - accuracy: 0.4934 - val_loss: 1.5208 - val_accuracy: 0.4702 - 2s/epoch - 36ms/step
# Epoch 18/30
# 50/50 - 2s - loss: 1.4235 - accuracy: 0.5011 - val_loss: 1.5118 - val_accuracy: 0.4670 - 2s/epoch - 37ms/step
# Epoch 19/30
# 50/50 - 2s - loss: 1.4209 - accuracy: 0.4989 - val_loss: 1.5262 - val_accuracy: 0.4657 - 2s/epoch - 36ms/step
# Epoch 20/30
# 50/50 - 2s - loss: 1.4073 - accuracy: 0.5081 - val_loss: 1.5400 - val_accuracy: 0.4650 - 2s/epoch - 36ms/step
# Epoch 21/30
# 50/50 - 2s - loss: 1.3968 - accuracy: 0.5094 - val_loss: 1.5083 - val_accuracy: 0.4714 - 2s/epoch - 36ms/step
# Epoch 22/30
# 50/50 - 2s - loss: 1.3786 - accuracy: 0.5174 - val_loss: 1.5016 - val_accuracy: 0.4716 - 2s/epoch - 36ms/step
# Epoch 23/30
# 50/50 - 2s - loss: 1.3764 - accuracy: 0.5181 - val_loss: 1.5328 - val_accuracy: 0.4602 - 2s/epoch - 36ms/step
# Epoch 24/30
# 50/50 - 2s - loss: 1.3626 - accuracy: 0.5232 - val_loss: 1.5000 - val_accuracy: 0.4706 - 2s/epoch - 37ms/step
# Epoch 25/30
# 50/50 - 2s - loss: 1.3550 - accuracy: 0.5238 - val_loss: 1.4909 - val_accuracy: 0.4766 - 2s/epoch - 36ms/step
# Epoch 26/30
# 50/50 - 2s - loss: 1.3536 - accuracy: 0.5245 - val_loss: 1.5061 - val_accuracy: 0.4694 - 2s/epoch - 36ms/step
# Epoch 27/30
# 50/50 - 2s - loss: 1.3525 - accuracy: 0.5252 - val_loss: 1.4810 - val_accuracy: 0.4812 - 2s/epoch - 37ms/step
# Epoch 28/30
# 50/50 - 2s - loss: 1.3368 - accuracy: 0.5282 - val_loss: 1.4837 - val_accuracy: 0.4806 - 2s/epoch - 36ms/step
# Epoch 29/30
# 50/50 - 2s - loss: 1.3303 - accuracy: 0.5324 - val_loss: 1.4892 - val_accuracy: 0.4761 - 2s/epoch - 36ms/step
# Epoch 30/30
# 50/50 - 2s - loss: 1.3207 - accuracy: 0.5342 - val_loss: 1.4744 - val_accuracy: 0.4858 - 2s/epoch - 36ms/step

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4518 - accuracy: 0.4905
#
# 	[Info] Accuracy of testing data = 49.1%

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Train_norm, y_TrainOneHot)  
print()  
print("\t[Info] Accuracy of training data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.3366 - accuracy: 0.5325
#
# 	[Info] Accuracy of training data = 53.3%

# %%
# %matplotlib inline
# accuracy chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
# %matplotlib inline
# loss chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
