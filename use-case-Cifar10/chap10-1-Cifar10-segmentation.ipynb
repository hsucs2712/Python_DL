# %%
# https://chatbotslife.com/cnn-image-classification-using-cifar-10-dataset-on-google-colab-tpu-750da8cd8510
# https://github.com/santanu13/CIFAR_10_Classification_TPU/blob/master/CIFAR_10_CLASSIFICATION_TPU.ipynb

# %%
#Import libraries
import os
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

#Download dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
#此處將數據轉換成灰階樣本
from skimage import color
from skimage import exposure
from skimage.transform import rescale
from skimage.util import random_noise
from skimage import segmentation
from skimage.color import label2rgb
import math
import matplotlib.pyplot as plt
modes = ['gaussian', 'localvar', 'poisson', 'salt', 'pepper', 's&p', 'speckle' ]

def imagepro(img, display):
    
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('Original')
        plt.imshow(img)
        plt.axis('off')
        plt.show()

    segments = segmentation.slic(img, start_label = 1, n_segments=math.ceil(32*32/(2*2))) #<--可以調
    sample = label2rgb(label=segments, image=img, kind='avg', bg_label=None).astype('uint8') # {'overlay', 'avg'}
    # sample = random_noise(img, mode= modes[2])
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('segmentation')
        plt.imshow(sample)
        plt.axis('off')
        plt.show()

    
    return sample
# 驗證
x = imagepro(img = x_train[1], display = True)

# %%
# 產生標籤
name2num = {'airplane' : 0,
            'automobile' : 1,
            'bird' : 2,
            'cat' : 3,
            'deer' : 4,
            'dog' : 5,
            'frog' : 6,
            'horse' : 7,
            'ship' : 8,
            'truck' : 9}
num2name = dict([(v,k) for (k,v) in name2num.items()])
num2name
# Out:
# {0: 'airplane',
#  1: 'automobile',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %%
# %%time
###########################################
#所有影像處理都在這裡
# source = x_train, x_test
# target = x_train_skimage, x_test_skiage
###########################################
x_train_skimage = np.array( [ imagepro(img = x, display = False) for x in x_train]  )
x_test_skimage = np.array(  [ imagepro(img = x, display = False) for x in x_test]  )
# Out:
# CPU times: user 8min 26s, sys: 1.38 s, total: 8min 28s
# Wall time: 8min 34s

# %%
# 請幫忙顯示十張truck 原來數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 請幫忙顯示十張truck 處理後數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train_skimage[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 檢視是否需要將數據進行處理 /255.0
# 更換數據
x_train_skimage[0].min(), x_train_skimage[0].max()
# Out:
# (2, 241)

# %%
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 
x_Test_norm = x_test_skimage.reshape(x_test_skimage.shape[0], 
                                     x_test_skimage.shape[1]*x_test_skimage.shape[2]*3).astype('float32')/255.0
del x_test_skimage
x_Train_norm = x_train_skimage.reshape(x_train_skimage.shape[0], 
                                       x_train_skimage.shape[1]*x_train_skimage.shape[2]*3).astype('float32')/255.0
del x_train_skimage

# %%
# y_TrainOneHot = np_utils.to_categorical(y_train) 
# y_TestOneHot = np_utils.to_categorical(y_test) 

# # 將 training 的 input 資料轉為2維
# x_train = x_train_skimage #<--------------preprocessed by skimage
# x_test  = x_test_skimage  #<--------------preprocessed by skimage

# X_train_2D = x_train.reshape(x_train.shape[0], 64*64*3).astype('float32')  
# X_test_2D = x_test.reshape(x_test.shape[0], 64*64*3).astype('float32')    
# x_Train_norm = X_train_2D /255.0  #<------
# x_Test_norm = X_test_2D   /255.0  #<------

# %%
# 建置model 
# 導入函式庫
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=x_Train_norm.shape[1], kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=30, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/30
# 50/50 - 3s - loss: 2.0564 - accuracy: 0.2549 - val_loss: 1.9148 - val_accuracy: 0.3136 - 3s/epoch - 54ms/step
# Epoch 2/30
# 50/50 - 2s - loss: 1.8590 - accuracy: 0.3455 - val_loss: 1.8355 - val_accuracy: 0.3467 - 2s/epoch - 38ms/step
# Epoch 3/30
# 50/50 - 2s - loss: 1.7854 - accuracy: 0.3776 - val_loss: 1.7744 - val_accuracy: 0.3766 - 2s/epoch - 38ms/step
# Epoch 4/30
# 50/50 - 2s - loss: 1.7268 - accuracy: 0.3946 - val_loss: 1.7363 - val_accuracy: 0.3863 - 2s/epoch - 38ms/step
# Epoch 5/30
# 50/50 - 3s - loss: 1.6874 - accuracy: 0.4070 - val_loss: 1.7089 - val_accuracy: 0.3934 - 3s/epoch - 52ms/step
# Epoch 6/30
# 50/50 - 2s - loss: 1.6501 - accuracy: 0.4204 - val_loss: 1.6827 - val_accuracy: 0.4113 - 2s/epoch - 44ms/step
# Epoch 7/30
# 50/50 - 2s - loss: 1.6243 - accuracy: 0.4306 - val_loss: 1.6632 - val_accuracy: 0.4206 - 2s/epoch - 37ms/step
# Epoch 8/30
# 50/50 - 2s - loss: 1.6052 - accuracy: 0.4385 - val_loss: 1.6446 - val_accuracy: 0.4244 - 2s/epoch - 37ms/step
# Epoch 9/30
# 50/50 - 2s - loss: 1.5877 - accuracy: 0.4433 - val_loss: 1.6437 - val_accuracy: 0.4292 - 2s/epoch - 38ms/step
# Epoch 10/30
# 50/50 - 2s - loss: 1.5683 - accuracy: 0.4495 - val_loss: 1.6162 - val_accuracy: 0.4306 - 2s/epoch - 37ms/step
# Epoch 11/30
# 50/50 - 2s - loss: 1.5521 - accuracy: 0.4560 - val_loss: 1.5938 - val_accuracy: 0.4427 - 2s/epoch - 37ms/step
# Epoch 12/30
# 50/50 - 2s - loss: 1.5465 - accuracy: 0.4586 - val_loss: 1.6001 - val_accuracy: 0.4416 - 2s/epoch - 37ms/step
# Epoch 13/30
# 50/50 - 2s - loss: 1.5252 - accuracy: 0.4647 - val_loss: 1.5786 - val_accuracy: 0.4491 - 2s/epoch - 37ms/step
# Epoch 14/30
# 50/50 - 2s - loss: 1.5137 - accuracy: 0.4674 - val_loss: 1.5677 - val_accuracy: 0.4501 - 2s/epoch - 37ms/step
# Epoch 15/30
# 50/50 - 2s - loss: 1.5011 - accuracy: 0.4729 - val_loss: 1.5676 - val_accuracy: 0.4503 - 2s/epoch - 38ms/step
# Epoch 16/30
# 50/50 - 2s - loss: 1.4925 - accuracy: 0.4773 - val_loss: 1.5628 - val_accuracy: 0.4512 - 2s/epoch - 37ms/step
# Epoch 17/30
# 50/50 - 2s - loss: 1.4750 - accuracy: 0.4821 - val_loss: 1.5558 - val_accuracy: 0.4524 - 2s/epoch - 37ms/step
# Epoch 18/30
# 50/50 - 2s - loss: 1.4642 - accuracy: 0.4883 - val_loss: 1.5461 - val_accuracy: 0.4602 - 2s/epoch - 37ms/step
# Epoch 19/30
# 50/50 - 2s - loss: 1.4601 - accuracy: 0.4873 - val_loss: 1.5522 - val_accuracy: 0.4533 - 2s/epoch - 37ms/step
# Epoch 20/30
# 50/50 - 2s - loss: 1.4486 - accuracy: 0.4929 - val_loss: 1.5367 - val_accuracy: 0.4628 - 2s/epoch - 38ms/step
# Epoch 21/30
# 50/50 - 2s - loss: 1.4443 - accuracy: 0.4946 - val_loss: 1.5240 - val_accuracy: 0.4648 - 2s/epoch - 37ms/step
# Epoch 22/30
# 50/50 - 2s - loss: 1.4336 - accuracy: 0.4983 - val_loss: 1.5238 - val_accuracy: 0.4650 - 2s/epoch - 37ms/step
# Epoch 23/30
# 50/50 - 2s - loss: 1.4250 - accuracy: 0.5015 - val_loss: 1.5414 - val_accuracy: 0.4585 - 2s/epoch - 37ms/step
# Epoch 24/30
# 50/50 - 2s - loss: 1.4160 - accuracy: 0.5043 - val_loss: 1.5137 - val_accuracy: 0.4680 - 2s/epoch - 37ms/step
# Epoch 25/30
# 50/50 - 2s - loss: 1.4135 - accuracy: 0.5037 - val_loss: 1.5386 - val_accuracy: 0.4611 - 2s/epoch - 37ms/step
# Epoch 26/30
# 50/50 - 2s - loss: 1.4081 - accuracy: 0.5056 - val_loss: 1.5244 - val_accuracy: 0.4667 - 2s/epoch - 38ms/step
# Epoch 27/30
# 50/50 - 2s - loss: 1.3952 - accuracy: 0.5117 - val_loss: 1.5204 - val_accuracy: 0.4656 - 2s/epoch - 37ms/step
# Epoch 28/30
# 50/50 - 2s - loss: 1.3916 - accuracy: 0.5094 - val_loss: 1.5174 - val_accuracy: 0.4728 - 2s/epoch - 37ms/step
# Epoch 29/30
# 50/50 - 2s - loss: 1.3838 - accuracy: 0.5146 - val_loss: 1.4882 - val_accuracy: 0.4807 - 2s/epoch - 37ms/step
# Epoch 30/30
# 50/50 - 2s - loss: 1.3778 - accuracy: 0.5179 - val_loss: 1.4822 - val_accuracy: 0.4858 - 2s/epoch - 37ms/step

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4576 - accuracy: 0.4881
#
# 	[Info] Accuracy of testing data = 48.8%

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Train_norm, y_TrainOneHot)  
print()  
print("\t[Info] Accuracy of training data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.3762 - accuracy: 0.5203
#
# 	[Info] Accuracy of training data = 52.0%

# %%
# %matplotlib inline
# accuracy chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
# %matplotlib inline
# loss chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
