# %%
# https://chatbotslife.com/cnn-image-classification-using-cifar-10-dataset-on-google-colab-tpu-750da8cd8510
# https://github.com/santanu13/CIFAR_10_Classification_TPU/blob/master/CIFAR_10_CLASSIFICATION_TPU.ipynb

# %%
#Import libraries
import os
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

#Download dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
print(x_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step
# (50000, 32, 32, 3)

# %%
#此處將數據轉換成灰階樣本
from skimage import color
from skimage import exposure
from skimage.transform import rescale
from skimage.util import random_noise
import matplotlib.pyplot as plt
modes = ['gaussian', 'localvar', 'poisson', 'salt', 'pepper', 's&p', 'speckle' ]

def imagepro(img, display):
    
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('Original')
        plt.imshow(img)
        plt.axis('off')
        plt.show()

    sample = random_noise(img, mode= modes[0])
    if display:
        plt.figure(figsize=(2, 2))
        plt.title('random_noise')
        plt.imshow(sample)
        plt.axis('off')
        plt.show()

    
    return sample
# 驗證
x = imagepro(img = x_train[1], display = True)

# %%
# 產生標籤
name2num = {'airplane' : 0,
            'automobile' : 1,
            'bird' : 2,
            'cat' : 3,
            'deer' : 4,
            'dog' : 5,
            'frog' : 6,
            'horse' : 7,
            'ship' : 8,
            'truck' : 9}
num2name = dict([(v,k) for (k,v) in name2num.items()])
num2name
# Out:
# {0: 'airplane',
#  1: 'automobile',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %%
# %%time
###########################################
#所有影像處理都在這裡
# source = x_train, x_test
# target = x_train_skimage, x_test_skiage
###########################################
x_train_skimage = np.array( [ imagepro(img = x, display = False) for x in x_train]  )
x_test_skimage = np.array(  [ imagepro(img = x, display = False) for x in x_test]  )
# Out:
# CPU times: user 14.8 s, sys: 880 ms, total: 15.6 s
# Wall time: 18 s

# %%
# 請幫忙顯示十張truck 原來數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 請幫忙顯示十張truck 處理後數據
# x_train, y_train
# 'truck' : 9
model = 2
x_train_filter = x_train_skimage[y_train.flatten()==model]

import matplotlib.pyplot as plt
for i in range(3):
    plt.figure(figsize=(2, 2))
    plt.title(num2name.get(model))
    plt.imshow(x_train_filter[i], cmap='gray')
    plt.axis('off')
    plt.show()

# %%
# 檢視是否需要將數據進行處理 /255.0
# 更換數據
x_train_skimage[0].min(), x_train_skimage[0].max()
# Out:
# (0.0, 1.0)

# %%
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 
x_Test_norm = x_test_skimage.reshape(x_test_skimage.shape[0], 
                                     x_test_skimage.shape[1]*x_test_skimage.shape[2]*3).astype('float32') # /255.0
del x_test_skimage
x_Train_norm = x_train_skimage.reshape(x_train_skimage.shape[0], 
                                       x_train_skimage.shape[1]*x_train_skimage.shape[2]*3).astype('float32')   #/255.0
del x_train_skimage

# %%
# y_TrainOneHot = np_utils.to_categorical(y_train) 
# y_TestOneHot = np_utils.to_categorical(y_test) 

# # 將 training 的 input 資料轉為2維
# x_train = x_train_skimage #<--------------preprocessed by skimage
# x_test  = x_test_skimage  #<--------------preprocessed by skimage

# X_train_2D = x_train.reshape(x_train.shape[0], 64*64*3).astype('float32')  
# X_test_2D = x_test.reshape(x_test.shape[0], 64*64*3).astype('float32')    
# x_Train_norm = X_train_2D /255.0  #<------
# x_Test_norm = X_test_2D   /255.0  #<------

# %%
# 建置model 
# 導入函式庫
import numpy as np  
import keras
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=x_Train_norm.shape[1], kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=30, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/30
# 50/50 - 2s - loss: 2.0444 - accuracy: 0.2629 - val_loss: 1.9037 - val_accuracy: 0.3322 - 2s/epoch - 48ms/step
# Epoch 2/30
# 50/50 - 2s - loss: 1.8459 - accuracy: 0.3503 - val_loss: 1.8247 - val_accuracy: 0.3574 - 2s/epoch - 35ms/step
# Epoch 3/30
# 50/50 - 2s - loss: 1.7786 - accuracy: 0.3763 - val_loss: 1.8022 - val_accuracy: 0.3590 - 2s/epoch - 35ms/step
# Epoch 4/30
# 50/50 - 2s - loss: 1.7311 - accuracy: 0.3914 - val_loss: 1.7454 - val_accuracy: 0.3817 - 2s/epoch - 34ms/step
# Epoch 5/30
# 50/50 - 2s - loss: 1.6894 - accuracy: 0.4076 - val_loss: 1.7298 - val_accuracy: 0.3858 - 2s/epoch - 34ms/step
# Epoch 6/30
# 50/50 - 2s - loss: 1.6627 - accuracy: 0.4166 - val_loss: 1.7105 - val_accuracy: 0.3955 - 2s/epoch - 35ms/step
# Epoch 7/30
# 50/50 - 2s - loss: 1.6279 - accuracy: 0.4281 - val_loss: 1.6844 - val_accuracy: 0.4062 - 2s/epoch - 34ms/step
# Epoch 8/30
# 50/50 - 2s - loss: 1.6020 - accuracy: 0.4387 - val_loss: 1.6627 - val_accuracy: 0.4114 - 2s/epoch - 35ms/step
# Epoch 9/30
# 50/50 - 2s - loss: 1.5865 - accuracy: 0.4410 - val_loss: 1.6688 - val_accuracy: 0.4067 - 2s/epoch - 34ms/step
# Epoch 10/30
# 50/50 - 2s - loss: 1.5639 - accuracy: 0.4548 - val_loss: 1.6350 - val_accuracy: 0.4226 - 2s/epoch - 34ms/step
# Epoch 11/30
# 50/50 - 2s - loss: 1.5385 - accuracy: 0.4632 - val_loss: 1.6202 - val_accuracy: 0.4265 - 2s/epoch - 34ms/step
# Epoch 12/30
# 50/50 - 2s - loss: 1.5253 - accuracy: 0.4660 - val_loss: 1.6385 - val_accuracy: 0.4210 - 2s/epoch - 34ms/step
# Epoch 13/30
# 50/50 - 2s - loss: 1.5045 - accuracy: 0.4756 - val_loss: 1.5961 - val_accuracy: 0.4380 - 2s/epoch - 34ms/step
# Epoch 14/30
# 50/50 - 2s - loss: 1.4973 - accuracy: 0.4787 - val_loss: 1.5961 - val_accuracy: 0.4368 - 2s/epoch - 34ms/step
# Epoch 15/30
# 50/50 - 2s - loss: 1.4895 - accuracy: 0.4807 - val_loss: 1.5851 - val_accuracy: 0.4369 - 2s/epoch - 35ms/step
# Epoch 16/30
# 50/50 - 2s - loss: 1.4656 - accuracy: 0.4876 - val_loss: 1.5907 - val_accuracy: 0.4394 - 2s/epoch - 34ms/step
# Epoch 17/30
# 50/50 - 2s - loss: 1.4526 - accuracy: 0.4945 - val_loss: 1.5842 - val_accuracy: 0.4413 - 2s/epoch - 35ms/step
# Epoch 18/30
# 50/50 - 2s - loss: 1.4354 - accuracy: 0.5013 - val_loss: 1.5876 - val_accuracy: 0.4391 - 2s/epoch - 34ms/step
# Epoch 19/30
# 50/50 - 2s - loss: 1.4282 - accuracy: 0.5031 - val_loss: 1.5727 - val_accuracy: 0.4444 - 2s/epoch - 35ms/step
# Epoch 20/30
# 50/50 - 2s - loss: 1.4095 - accuracy: 0.5099 - val_loss: 1.5528 - val_accuracy: 0.4503 - 2s/epoch - 34ms/step
# Epoch 21/30
# 50/50 - 2s - loss: 1.4052 - accuracy: 0.5133 - val_loss: 1.5811 - val_accuracy: 0.4408 - 2s/epoch - 34ms/step
# Epoch 22/30
# 50/50 - 2s - loss: 1.3933 - accuracy: 0.5148 - val_loss: 1.5573 - val_accuracy: 0.4448 - 2s/epoch - 34ms/step
# Epoch 23/30
# 50/50 - 2s - loss: 1.3815 - accuracy: 0.5166 - val_loss: 1.5399 - val_accuracy: 0.4537 - 2s/epoch - 44ms/step
# Epoch 24/30
# 50/50 - 2s - loss: 1.3712 - accuracy: 0.5240 - val_loss: 1.5353 - val_accuracy: 0.4608 - 2s/epoch - 46ms/step
# Epoch 25/30
# 50/50 - 2s - loss: 1.3562 - accuracy: 0.5264 - val_loss: 1.5596 - val_accuracy: 0.4520 - 2s/epoch - 35ms/step
# Epoch 26/30
# 50/50 - 2s - loss: 1.3518 - accuracy: 0.5279 - val_loss: 1.5412 - val_accuracy: 0.4530 - 2s/epoch - 34ms/step
# Epoch 27/30
# 50/50 - 2s - loss: 1.3390 - accuracy: 0.5360 - val_loss: 1.5295 - val_accuracy: 0.4561 - 2s/epoch - 34ms/step
# Epoch 28/30
# 50/50 - 2s - loss: 1.3199 - accuracy: 0.5435 - val_loss: 1.5246 - val_accuracy: 0.4675 - 2s/epoch - 34ms/step
# Epoch 29/30
# 50/50 - 2s - loss: 1.3147 - accuracy: 0.5447 - val_loss: 1.5349 - val_accuracy: 0.4587 - 2s/epoch - 34ms/step
# Epoch 30/30
# 50/50 - 2s - loss: 1.3141 - accuracy: 0.5432 - val_loss: 1.5295 - val_accuracy: 0.4576 - 2s/epoch - 35ms/step

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 1.4956 - accuracy: 0.4716
#
# 	[Info] Accuracy of testing data = 47.2%

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Train_norm, y_TrainOneHot)  
print()  
print("\t[Info] Accuracy of training data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 1563/1563 [==============================] - 2s 2ms/step - loss: 1.3336 - accuracy: 0.5345
#
# 	[Info] Accuracy of training data = 53.5%

# %%
# %matplotlib inline
# accuracy chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
# %matplotlib inline
# loss chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
