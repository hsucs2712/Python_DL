# %%
# binary_dilation

# %%
# 導入函式庫
import numpy as np  
import keras
# from keras.models import Sequential
from keras.datasets import mnist
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  
from matplotlib import pyplot as plt
import os
from datetime import datetime

start=datetime.now()

# 載入 MNIST 資料庫的訓練資料，並自動分為『訓練組』及『測試組』
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=28*28, kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# 可以試試這樣做 僅是部分資料
from tqdm import tqdm # 跑出步近圖
import numpy as np
from skimage.filters import gaussian
from skimage.filters import sobel
from skimage import exposure
from skimage.transform import rescale
from skimage import morphology

X_train_skimage = np.array([morphology.binary_erosion(x) for x in X_train[:]]) # <--核心價值 change me
X_test_skimage = np.array([morphology.binary_erosion(x) for x in X_test[:]])  # <--核心價值 change me
print('Preprocessed by skimage.rescale')
# Out:
# Preprocessed by skimage.rescale
# Wall time: 19.6 s

# %%
# 劃出一 原來圖片
plt.figure(figsize=(2,2))
plt.imshow(X_train[0], cmap='gray')
plt.axis('off')
plt.show()

# %%
# 劃出一圖片
plt.figure(figsize=(2,2))
plt.imshow(X_train_skimage[0], cmap='gray')
plt.axis('off')
plt.show()
print('Data range after preprocessed', X_train_skimage[0].min(), X_train_skimage[0].max())
# Out:
# Data range after preprocessed False True

# %%
# 將 training 的 label 進行 one-hot encoding，例如數字 7 經過 One-hot encoding 轉換後是 0000001000，即第7個值為 1
y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 

# 將 training 的 input 資料轉為2維
X_train = X_train_skimage #<--------------preprocessed by skimage
X_test  = X_test_skimage  #<--------------preprocessed by skimage

X_train_2D = X_train.reshape(60000, 28*28).astype('float32')  #< -----
X_test_2D = X_test.reshape(10000, 28*28).astype('float32')    #< -----

x_Train_norm = X_train_2D # /255.0  #<-------取消
x_Test_norm = X_test_2D   # /255.0  #<-------取消

# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=40, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/40
# 60/60 - 5s - loss: 1.1479 - accuracy: 0.7224 - val_loss: 0.5258 - val_accuracy: 0.8587
# Epoch 2/40
# 60/60 - 1s - loss: 0.4684 - accuracy: 0.8714 - val_loss: 0.3863 - val_accuracy: 0.8922
# Epoch 3/40
# 60/60 - 1s - loss: 0.3797 - accuracy: 0.8932 - val_loss: 0.3363 - val_accuracy: 0.9057
# Epoch 4/40
# 60/60 - 1s - loss: 0.3316 - accuracy: 0.9061 - val_loss: 0.3029 - val_accuracy: 0.9129
# Epoch 5/40
# 60/60 - 1s - loss: 0.2980 - accuracy: 0.9164 - val_loss: 0.2795 - val_accuracy: 0.9217
# Epoch 6/40
# 60/60 - 1s - loss: 0.2694 - accuracy: 0.9241 - val_loss: 0.2583 - val_accuracy: 0.9260
# Epoch 7/40
# 60/60 - 1s - loss: 0.2469 - accuracy: 0.9303 - val_loss: 0.2424 - val_accuracy: 0.9319
# Epoch 8/40
# 60/60 - 1s - loss: 0.2278 - accuracy: 0.9368 - val_loss: 0.2332 - val_accuracy: 0.9332
# Epoch 9/40
# 60/60 - 1s - loss: 0.2107 - accuracy: 0.9413 - val_loss: 0.2198 - val_accuracy: 0.9383
# Epoch 10/40
# 60/60 - 1s - loss: 0.1966 - accuracy: 0.9448 - val_loss: 0.2104 - val_accuracy: 0.9402
# Epoch 11/40
# 60/60 - 1s - loss: 0.1841 - accuracy: 0.9489 - val_loss: 0.2057 - val_accuracy: 0.9415
# Epoch 12/40
# 60/60 - 2s - loss: 0.1729 - accuracy: 0.9524 - val_loss: 0.1970 - val_accuracy: 0.9445
# Epoch 13/40
# 60/60 - 2s - loss: 0.1639 - accuracy: 0.9551 - val_loss: 0.1908 - val_accuracy: 0.9461
# Epoch 14/40
# 60/60 - 1s - loss: 0.1533 - accuracy: 0.9588 - val_loss: 0.1875 - val_accuracy: 0.9459
# Epoch 15/40
# 60/60 - 1s - loss: 0.1459 - accuracy: 0.9600 - val_loss: 0.1871 - val_accuracy: 0.9459
# Epoch 16/40
# 60/60 - 1s - loss: 0.1386 - accuracy: 0.9619 - val_loss: 0.1794 - val_accuracy: 0.9473
# Epoch 17/40
# 60/60 - 1s - loss: 0.1308 - accuracy: 0.9648 - val_loss: 0.1755 - val_accuracy: 0.9484
# Epoch 18/40
# 60/60 - 1s - loss: 0.1242 - accuracy: 0.9667 - val_loss: 0.1728 - val_accuracy: 0.9482
# Epoch 19/40
# 60/60 - 1s - loss: 0.1185 - accuracy: 0.9684 - val_loss: 0.1714 - val_accuracy: 0.9505
# Epoch 20/40
# 60/60 - 0s - loss: 0.1125 - accuracy: 0.9694 - val_loss: 0.1673 - val_accuracy: 0.9504
# Epoch 21/40
# 60/60 - 0s - loss: 0.1066 - accuracy: 0.9726 - val_loss: 0.1659 - val_accuracy: 0.9515
# Epoch 22/40
# 60/60 - 0s - loss: 0.1020 - accuracy: 0.9732 - val_loss: 0.1617 - val_accuracy: 0.9534
# Epoch 23/40
# 60/60 - 1s - loss: 0.0968 - accuracy: 0.9752 - val_loss: 0.1609 - val_accuracy: 0.9533
# Epoch 24/40
# 60/60 - 1s - loss: 0.0920 - accuracy: 0.9764 - val_loss: 0.1604 - val_accuracy: 0.9533
# Epoch 25/40
# 60/60 - 0s - loss: 0.0879 - accuracy: 0.9781 - val_loss: 0.1595 - val_accuracy: 0.9532
# Epoch 26/40
# 60/60 - 1s - loss: 0.0841 - accuracy: 0.9784 - val_loss: 0.1587 - val_accuracy: 0.9533
# Epoch 27/40
# 60/60 - 1s - loss: 0.0802 - accuracy: 0.9796 - val_loss: 0.1575 - val_accuracy: 0.9542
# Epoch 28/40
# 60/60 - 1s - loss: 0.0765 - accuracy: 0.9811 - val_loss: 0.1558 - val_accuracy: 0.9557
# Epoch 29/40
# 60/60 - 1s - loss: 0.0728 - accuracy: 0.9821 - val_loss: 0.1557 - val_accuracy: 0.9555
# Epoch 30/40
# 60/60 - 0s - loss: 0.0697 - accuracy: 0.9837 - val_loss: 0.1580 - val_accuracy: 0.9543
# Epoch 31/40
# 60/60 - 1s - loss: 0.0659 - accuracy: 0.9841 - val_loss: 0.1564 - val_accuracy: 0.9553
# Epoch 32/40
# 60/60 - 0s - loss: 0.0626 - accuracy: 0.9852 - val_loss: 0.1551 - val_accuracy: 0.9563
# Epoch 33/40
# 60/60 - 1s - loss: 0.0600 - accuracy: 0.9862 - val_loss: 0.1548 - val_accuracy: 0.9557
# Epoch 34/40
# 60/60 - 1s - loss: 0.0567 - accuracy: 0.9872 - val_loss: 0.1549 - val_accuracy: 0.9568
# Epoch 35/40
# 60/60 - 2s - loss: 0.0544 - accuracy: 0.9875 - val_loss: 0.1549 - val_accuracy: 0.9562
# Epoch 36/40
# 60/60 - 1s - loss: 0.0518 - accuracy: 0.9884 - val_loss: 0.1564 - val_accuracy: 0.9551
# Epoch 37/40
# 60/60 - 3s - loss: 0.0495 - accuracy: 0.9889 - val_loss: 0.1561 - val_accuracy: 0.9579
# Epoch 38/40
# 60/60 - 1s - loss: 0.0474 - accuracy: 0.9899 - val_loss: 0.1569 - val_accuracy: 0.9576
# Epoch 39/40
# 60/60 - 1s - loss: 0.0449 - accuracy: 0.9905 - val_loss: 0.1567 - val_accuracy: 0.9572
# Epoch 40/40
# 60/60 - 1s - loss: 0.0428 - accuracy: 0.9912 - val_loss: 0.1561 - val_accuracy: 0.9576

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 4s 11ms/step - loss: 0.1636 - accuracy: 0.9547
#
# 	[Info] Accuracy of testing data = 95.5%

# %%
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
