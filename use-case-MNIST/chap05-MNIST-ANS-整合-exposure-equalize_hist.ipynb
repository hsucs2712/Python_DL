# %%
# 導入函式庫
import numpy as np  
import keras
# from keras.models import Sequential
from keras.datasets import mnist
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  
from matplotlib import pyplot as plt
import os
from datetime import datetime

start=datetime.now()

# 載入 MNIST 資料庫的訓練資料，並自動分為『訓練組』及『測試組』
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=28*28, kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# 可以試試這樣做 僅是部分資料
from tqdm import tqdm # 跑出步近圖
import numpy as np
from skimage.filters import gaussian
from skimage.filters import sobel
from skimage import exposure
# exposure.equalize_adapthist
# exposure.equalize_hist
X_train_skimage = np.array([exposure.equalize_hist(image = x) for x in X_train[:]]) # <--核心價值 change me
X_test_skimage = np.array([exposure.equalize_hist(image = x) for x in X_test[:]])  # <--核心價值 change me
print('Preprocessed by skimage.exposure')
# Out:
# Preprocessed by skimage.exposure
# CPU times: user 4.23 s, sys: 648 ms, total: 4.87 s
# Wall time: 5.3 s

# %%
# 劃出一 原來圖片
plt.figure(figsize=(2,2))
plt.imshow(X_train[0], cmap='gray')
plt.axis('off')
plt.show()

# %%
# 劃出一圖片
plt.figure(figsize=(2,2))
plt.imshow(X_train_skimage[0], cmap='gray')
plt.axis('off')
plt.show()
print('Data range after preprocessed', X_train_skimage[0].min(), X_train_skimage[0].max())
# Out:
# Data range after preprocessed 0.7882653061224489 1.0

# %%
# 將 training 的 label 進行 one-hot encoding，例如數字 7 經過 One-hot encoding 轉換後是 0000001000，即第7個值為 1
y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 

# 將 training 的 input 資料轉為2維
X_train = X_train_skimage #<--------------preprocessed by skimage
X_test  = X_test_skimage  #<--------------preprocessed by skimage

X_train_2D = X_train.reshape(60000, 28*28).astype('float32')  #< -----
X_test_2D = X_test.reshape(10000, 28*28).astype('float32')    #< -----

x_Train_norm = X_train_2D # /255.0  #<-------取消
x_Test_norm = X_test_2D   # /255.0  #<-------取消

# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=10, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/10
# 60/60 - 1s - loss: 2.2829 - accuracy: 0.1481 - val_loss: 2.2418 - val_accuracy: 0.1691 - 1s/epoch - 23ms/step
# Epoch 2/10
# 60/60 - 1s - loss: 2.1783 - accuracy: 0.2976 - val_loss: 2.0921 - val_accuracy: 0.3953 - 633ms/epoch - 11ms/step
# Epoch 3/10
# 60/60 - 1s - loss: 1.9824 - accuracy: 0.4136 - val_loss: 1.8491 - val_accuracy: 0.5092 - 654ms/epoch - 11ms/step
# Epoch 4/10
# 60/60 - 1s - loss: 1.7440 - accuracy: 0.5356 - val_loss: 1.6182 - val_accuracy: 0.5727 - 630ms/epoch - 10ms/step
# Epoch 5/10
# 60/60 - 1s - loss: 1.5249 - accuracy: 0.6201 - val_loss: 1.4056 - val_accuracy: 0.6557 - 621ms/epoch - 10ms/step
# Epoch 6/10
# 60/60 - 1s - loss: 1.3430 - accuracy: 0.6650 - val_loss: 1.2433 - val_accuracy: 0.6959 - 634ms/epoch - 11ms/step
# Epoch 7/10
# 60/60 - 1s - loss: 1.1988 - accuracy: 0.6982 - val_loss: 1.1416 - val_accuracy: 0.6608 - 623ms/epoch - 10ms/step
# Epoch 8/10
# 60/60 - 1s - loss: 1.1008 - accuracy: 0.7129 - val_loss: 1.0109 - val_accuracy: 0.7541 - 619ms/epoch - 10ms/step
# Epoch 9/10
# 60/60 - 1s - loss: 1.0113 - accuracy: 0.7397 - val_loss: 0.9666 - val_accuracy: 0.7362 - 628ms/epoch - 10ms/step
# Epoch 10/10
# 60/60 - 1s - loss: 0.9442 - accuracy: 0.7532 - val_loss: 0.8818 - val_accuracy: 0.7786 - 610ms/epoch - 10ms/step

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8854 - accuracy: 0.7771
#
# 	[Info] Accuracy of testing data = 77.7%

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Train_norm, y_TrainOneHot)  
print()  
print("\t[Info] Accuracy of training data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9080 - accuracy: 0.7676
#
# 	[Info] Accuracy of training data = 76.8%

# %%
# %matplotlib inline
# accuracy chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
# %matplotlib inline
# loss chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
