# %%
# binary_dilation

# %%
# 導入函式庫
import numpy as np  
import keras
# from keras.models import Sequential
from keras.datasets import mnist
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils  # 用來後續將 label 標籤轉為 one-hot-encoding  
from matplotlib import pyplot as plt
import os
from datetime import datetime

start=datetime.now()

# 載入 MNIST 資料庫的訓練資料，並自動分為『訓練組』及『測試組』
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=128, input_dim=28*28, kernel_initializer='normal', activation='relu')) 
# Add output layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# 編譯: 選擇損失函數、優化方法及成效衡量方式
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# 可以試試這樣做 僅是部分資料
from tqdm import tqdm # 跑出步近圖
import numpy as np
from skimage.filters import gaussian
from skimage.filters import sobel
from skimage import exposure
from skimage.transform import rescale
from skimage import morphology

X_train_skimage = np.array([morphology.binary_dilation(x) for x in X_train[:]]) # <--核心價值 change me
X_test_skimage = np.array([morphology.binary_dilation(x) for x in X_test[:]])  # <--核心價值 change me
print('Preprocessed by skimage.rescale')
# Out:
# Preprocessed by skimage.rescale
# Wall time: 6.25 s

# %%
# 劃出一 原來圖片
plt.figure(figsize=(2,2))
plt.imshow(X_train[0], cmap='gray')
plt.axis('off')
plt.show()

# %%
# 劃出一圖片
plt.figure(figsize=(2,2))
plt.imshow(X_train_skimage[0], cmap='gray')
plt.axis('off')
plt.show()
print('Data range after preprocessed', X_train_skimage[0].min(), X_train_skimage[0].max())
# Out:
# Data range after preprocessed False True

# %%
# 將 training 的 label 進行 one-hot encoding，例如數字 7 經過 One-hot encoding 轉換後是 0000001000，即第7個值為 1
y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 

# 將 training 的 input 資料轉為2維
X_train = X_train_skimage #<--------------preprocessed by skimage
X_test  = X_test_skimage  #<--------------preprocessed by skimage

X_train_2D = X_train.reshape(60000, 28*28).astype('float32')  #< -----
X_test_2D = X_test.reshape(10000, 28*28).astype('float32')    #< -----

x_Train_norm = X_train_2D # /255.0  #<-------取消
x_Test_norm = X_test_2D   # /255.0  #<-------取消

# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=x_Train_norm, y=y_TrainOneHot, 
                          validation_split=0.2, epochs=40, 
                          batch_size=800, verbose=2)
# Out:
# Epoch 1/40
# 60/60 - 3s - loss: 0.9468 - accuracy: 0.7523 - val_loss: 0.4296 - val_accuracy: 0.8758
# Epoch 2/40
# 60/60 - 1s - loss: 0.4034 - accuracy: 0.8782 - val_loss: 0.3417 - val_accuracy: 0.8978
# Epoch 3/40
# 60/60 - 1s - loss: 0.3372 - accuracy: 0.8984 - val_loss: 0.3020 - val_accuracy: 0.9078
# Epoch 4/40
# 60/60 - 2s - loss: 0.2981 - accuracy: 0.9094 - val_loss: 0.2737 - val_accuracy: 0.9148
# Epoch 5/40
# 60/60 - 2s - loss: 0.2677 - accuracy: 0.9185 - val_loss: 0.2484 - val_accuracy: 0.9222
# Epoch 6/40
# 60/60 - 1s - loss: 0.2413 - accuracy: 0.9262 - val_loss: 0.2312 - val_accuracy: 0.9272
# Epoch 7/40
# 60/60 - 0s - loss: 0.2222 - accuracy: 0.9319 - val_loss: 0.2213 - val_accuracy: 0.9293
# Epoch 8/40
# 60/60 - 1s - loss: 0.2065 - accuracy: 0.9371 - val_loss: 0.2117 - val_accuracy: 0.9330
# Epoch 9/40
# 60/60 - 0s - loss: 0.1943 - accuracy: 0.9411 - val_loss: 0.1989 - val_accuracy: 0.9367
# Epoch 10/40
# 60/60 - 1s - loss: 0.1806 - accuracy: 0.9449 - val_loss: 0.1967 - val_accuracy: 0.9342
# Epoch 11/40
# 60/60 - 0s - loss: 0.1708 - accuracy: 0.9482 - val_loss: 0.1891 - val_accuracy: 0.9387
# Epoch 12/40
# 60/60 - 1s - loss: 0.1604 - accuracy: 0.9510 - val_loss: 0.1816 - val_accuracy: 0.9427
# Epoch 13/40
# 60/60 - 1s - loss: 0.1512 - accuracy: 0.9547 - val_loss: 0.1754 - val_accuracy: 0.9441
# Epoch 14/40
# 60/60 - 1s - loss: 0.1433 - accuracy: 0.9569 - val_loss: 0.1759 - val_accuracy: 0.9428
# Epoch 15/40
# 60/60 - 1s - loss: 0.1365 - accuracy: 0.9596 - val_loss: 0.1708 - val_accuracy: 0.9452
# Epoch 16/40
# 60/60 - 0s - loss: 0.1286 - accuracy: 0.9616 - val_loss: 0.1652 - val_accuracy: 0.9480
# Epoch 17/40
# 60/60 - 0s - loss: 0.1244 - accuracy: 0.9627 - val_loss: 0.1645 - val_accuracy: 0.9471
# Epoch 18/40
# 60/60 - 0s - loss: 0.1192 - accuracy: 0.9639 - val_loss: 0.1646 - val_accuracy: 0.9478
# Epoch 19/40
# 60/60 - 0s - loss: 0.1125 - accuracy: 0.9664 - val_loss: 0.1563 - val_accuracy: 0.9507
# Epoch 20/40
# 60/60 - 0s - loss: 0.1064 - accuracy: 0.9682 - val_loss: 0.1580 - val_accuracy: 0.9498
# Epoch 21/40
# 60/60 - 0s - loss: 0.1026 - accuracy: 0.9696 - val_loss: 0.1548 - val_accuracy: 0.9518
# Epoch 22/40
# 60/60 - 0s - loss: 0.0992 - accuracy: 0.9704 - val_loss: 0.1518 - val_accuracy: 0.9524
# Epoch 23/40
# 60/60 - 1s - loss: 0.0939 - accuracy: 0.9721 - val_loss: 0.1494 - val_accuracy: 0.9530
# Epoch 24/40
# 60/60 - 1s - loss: 0.0904 - accuracy: 0.9727 - val_loss: 0.1556 - val_accuracy: 0.9519
# Epoch 25/40
# 60/60 - 0s - loss: 0.0860 - accuracy: 0.9747 - val_loss: 0.1489 - val_accuracy: 0.9531
# Epoch 26/40
# 60/60 - 0s - loss: 0.0825 - accuracy: 0.9762 - val_loss: 0.1502 - val_accuracy: 0.9537
# Epoch 27/40
# 60/60 - 0s - loss: 0.0795 - accuracy: 0.9771 - val_loss: 0.1484 - val_accuracy: 0.9531
# Epoch 28/40
# 60/60 - 1s - loss: 0.0770 - accuracy: 0.9775 - val_loss: 0.1475 - val_accuracy: 0.9530
# Epoch 29/40
# 60/60 - 0s - loss: 0.0733 - accuracy: 0.9787 - val_loss: 0.1441 - val_accuracy: 0.9543
# Epoch 30/40
# 60/60 - 0s - loss: 0.0702 - accuracy: 0.9796 - val_loss: 0.1473 - val_accuracy: 0.9535
# Epoch 31/40
# 60/60 - 0s - loss: 0.0684 - accuracy: 0.9803 - val_loss: 0.1434 - val_accuracy: 0.9558
# Epoch 32/40
# 60/60 - 0s - loss: 0.0654 - accuracy: 0.9818 - val_loss: 0.1435 - val_accuracy: 0.9554
# Epoch 33/40
# 60/60 - 0s - loss: 0.0628 - accuracy: 0.9828 - val_loss: 0.1525 - val_accuracy: 0.9528
# Epoch 34/40
# 60/60 - 0s - loss: 0.0609 - accuracy: 0.9826 - val_loss: 0.1439 - val_accuracy: 0.9556
# Epoch 35/40
# 60/60 - 0s - loss: 0.0582 - accuracy: 0.9838 - val_loss: 0.1426 - val_accuracy: 0.9556
# Epoch 36/40
# 60/60 - 0s - loss: 0.0545 - accuracy: 0.9854 - val_loss: 0.1480 - val_accuracy: 0.9547
# Epoch 37/40
# 60/60 - 0s - loss: 0.0532 - accuracy: 0.9862 - val_loss: 0.1447 - val_accuracy: 0.9558
# Epoch 38/40
# 60/60 - 0s - loss: 0.0512 - accuracy: 0.9864 - val_loss: 0.1451 - val_accuracy: 0.9573
# Epoch 39/40
# 60/60 - 0s - loss: 0.0494 - accuracy: 0.9875 - val_loss: 0.1434 - val_accuracy: 0.9570
# Epoch 40/40
# 60/60 - 0s - loss: 0.0467 - accuracy: 0.9876 - val_loss: 0.1439 - val_accuracy: 0.9563

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1375 - accuracy: 0.9602
#
# 	[Info] Accuracy of testing data = 96.0%

# %%
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.grid()
plt.show()
