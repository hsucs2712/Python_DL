# %%
# !mkdir  -p reviews

# %%
# !pip install azure-ai-textanalytics==5.1.0

# %%
#from dotenv import load_dotenv
import os
import requests, json

def main():
    global translator_endpoint
    global cog_key
    global cog_region

    try:
        # Get Configuration Settings
        #load_dotenv()
        cog_key = 'f4ad5afcb99b4e769720ee7b16f098d3' #os.getenv('COG_SERVICE_KEY')
        cog_region = 'eastasia' #os.getenv('COG_SERVICE_REGION')
        translator_endpoint = 'https://api.cognitive.microsofttranslator.com'

        # Analyze each text file in the reviews folder
        reviews_folder = 'reviews'
        for file_name in sorted(os.listdir(reviews_folder)):
            # Read the file contents
            print('\n-------------\n' + file_name)
            text = open(os.path.join(reviews_folder, file_name), encoding='utf8').read()
            print('\n' + text)

            # Detect the language
            language = GetLanguage(text)
            print('Language:',language)

            # Translate if not already English
            if language != 'zh-hans': #<-----------關鍵地方就是 非中文就翻譯
                translation = Translate(text, language)
                print("\nTranslation:\n{}".format(translation))
                
    except Exception as ex:
        print(ex)

def GetLanguage(text):
    # Default language is English
    language = 'en'

    # Use the Translator detect function
    path = '/detect'
    url = translator_endpoint + path

    # Build the request
    params = {
        'api-version': '3.0'
    }

    headers = {
    'Ocp-Apim-Subscription-Key': cog_key,
    'Ocp-Apim-Subscription-Region': cog_region,
    'Content-type': 'application/json'
    }

    body = [{
        'text': text
    }]

    # Send the request and get response
    request = requests.post(url, params=params, headers=headers, json=body)
    response = request.json()

    # Parse JSON array and get language
    language = response[0]["language"]


    # Return the language
    return language

def Translate(text, source_language):
    translation = ''

    # Use the Translator translate function
    path = '/translate'
    url = translator_endpoint + path

    # Build the request
    params = {
        'api-version': '3.0',
        'from': source_language,
        'to': ['zh-hans'] #<-----------關鍵地方就是 非中文就翻譯 成什麼語言
    }

    headers = {
        'Ocp-Apim-Subscription-Key': cog_key,
        'Ocp-Apim-Subscription-Region': cog_region,
        'Content-type': 'application/json'
    }

    body = [{
        'text': text
    }]

    # Send the request and get response
    request = requests.post(url, params=params, headers=headers, json=body)
    response = request.json()

    # Parse JSON array and get translation
    translation = response[0]["translations"][0]["text"]


    # Return the translation
    return translation

if __name__ == "__main__":
    main()
# Out:
# -------------
# review1.txt
#
# Good Hotel and staff
# The Royal Hotel, London, UK
# 3/2/2018
# Clean rooms, good service, great location near Buckingham Palace and Westminster Abbey, and so on. We thoroughly enjoyed our stay. The courtyard is very peaceful and we went to a restaurant which is part of the same group and is Indian ( West coast so plenty of fish) with a Michelin Star. We had the taster menu which was fabulous. The rooms were very well appointed with a kitchen, lounge, bedroom and enormous bathroom. Thoroughly recommended.
# Language: en
#
# Translation:
# 良いホテルとスタッフ
# ザ ロイヤル ホテル、ロンドン、イギリス
# 3/2/2018
# 清潔な客室、優れたサービス、バッキンガム宮殿とウェストミンスター寺院の近くの素晴らしいロケーションなど。私たちは徹底的に私たちの滞在を楽しんだ。中庭はとても平和で、私たちは同じグループの一員であり、ミシュランの星を持つインド(西海岸はとてもたくさんの魚)であるレストランに行きました。私たちは素晴らしいテイスターメニューを持っていました。客室にはキッチン、ラウンジ、ベッドルーム、巨大なバスルームが備わりました。徹底的にお勧めします。
#
# -------------
# review2.txt
#
# Tired hotel with poor service
# The Royal Hotel, London, United Kingdom
# 5/6/2018
# This is a old hotel (has been around since 1950's) and the room furnishings are average - becoming a bit old now and require changing. The internet didn't work and had to come to one of their office rooms to check in for my flight home. The website says it's close to the British Museum, but it's too far to walk.
# Language: en
#
# Translation:
# サービスが悪い疲れたホテル
# ザ ロイヤル ホテル、ロンドン、イギリス
# 5/6/2018
# これは古いホテル(1950年代から存在しています)で、部屋の家具は平均的です - 今少し古くなり、変更する必要があります。インターネットは機能せず、私の帰りのフライトをチェックインするために彼らのオフィスルームの1つに来なければなりませんでした。ウェブサイトには、大英博物館の近くにあると書かれていますが、歩くには遠すぎます。
#
# -------------
# review3.txt
#
# Good location and helpful staff, but on a busy road.
# The Lombard Hotel, San Francisco, USA
# 8/16/2018
# We stayed here in August after reading reviews. We were very pleased with location, just behind Chestnut Street, a cosmopolitan and trendy area with plenty of restaurants to choose from. The
# Marina district was lovely to wander through, very interesting houses. Make sure to walk to the San Francisco Museum of Fine Arts and the Marina to get a good view of Golden Gate bridge and the city. On a bus route and easy to get into centre. Rooms were clean with plenty of room and staff were friendly and helpful. The only down side was the noise from Lombard Street so ask to have a room furthest away from traffic noise.
# Language: en
#
# Translation:
# 良い場所と親切なスタッフ、しかし忙しい道路上。
# ザ ロンバード ホテル、サンフランシスコ、アメリカ
# 8/16/2018
# レビューを読んだ後、8月にここに滞在しました。私たちは、チェスナットストリートのすぐ後ろ、コスモポリタンでトレンディなエリアのすぐ後ろにある場所に非常に満足していました。ザ
# マリーナ地区は、非常に興味深い家々をさまようのが素敵でした。サンフランシスコ美術館とマリーナまで歩いて、ゴールデンゲートブリッジと街の素晴らしい景色を眺めましょう。バス路線で、中心部に簡単にアクセスできます。部屋は清潔で十分な部屋があり、スタッフはフレンドリーで親切でした。唯一の欠点はロンバードストリートからの騒音だったので、交通騒音から最も離れた部屋を持つように頼んでください。
#
# -------------
# review4.txt
#
# Very noisy and rooms are tiny
# The Lombard Hotel, San Francisco, USA
# 9/5/2018
# Hotel is located on Lombard street which is a very busy SIX lane street directly off the Golden Gate Bridge. Traffic from early morning until late at night especially on weekends. Noise would not be so bad if rooms were better insulated but they are not. Had to put cotton balls in my ears to be able to sleep--was too tired to enjoy the city the next day. Rooms are TINY. I picked the room because it had two queen size beds--but the room barely had space to fit them. With family of four in the room it was tight. With all that said, rooms are clean and they've made an effort to update them. The hotel is in Marina district with lots of good places to eat, within walking distance to Presidio. May be good hotel for young stay-up-late adults on a budget
#
# Language: en
#
# Translation:
# 非常に騒々しく、部屋は小さいです
# ザ ロンバード ホテル、サンフランシスコ、アメリカ
# 9/5/2018
# ホテルは、ゴールデンゲートブリッジのすぐそばにある非常に忙しいSIXレーンストリートであるロンバードストリートに位置しています。特に週末の早朝から深夜までの交通量。部屋がもっと断熱されていれば騒音はそれほど悪くないでしょうが、そうではありません。眠れるようにコットンボールを耳に入れなければならなかった――疲れすぎて翌日の街を楽しむことができなかった。部屋は狭い。クイーンサイズのベッドが2台あったので、部屋を選んだのですが、部屋にはそれらを収容するスペースがほとんどありませんでした。部屋には4人家族がいて、きついものでした。そうは言っても、部屋は清潔で、彼らはそれらを更新する努力をしました。当ホテルはマリーナ地区にあり、プレシディオまで徒歩圏内にあり、食事をするのに最適な場所がたくさんあります。予算上の若い滞在-遅い大人のための良いホテルかもしれません
#
#
# -------------
# review5.txt
#
# Un hôtel agréable
# L'Hotel Buckingham, Londres, UK
# J’adore cet hôtel. Le personnel est très amical et les chambres sont confortables.
# Language: fr
#
# Translation:
# 快適なホテル
# ザ ホテル バッキンガム, ロンドン, イギリス
# このホテルが大好きです。スタッフはとてもフレンドリーで、客室は快適です。
