# %%
import matplotlib.pyplot as plt
bear = plt.imread('polarbear.jpg')
plt.imshow(bear)
plt.axis('off')
plt.show()

# %%
plt.hist(bear.flatten(), bins=256)
plt.show()

# %%
import matplotlib.pyplot as plt
moon = plt.imread('moon.jpg')
plt.imshow(moon)
plt.axis('off')
plt.show()

# %%
plt.hist(moon.flatten(), bins=256)
plt.show()
