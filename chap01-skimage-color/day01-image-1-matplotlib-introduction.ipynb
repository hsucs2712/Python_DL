# %%
# !pwd
# !ls -rtl
# !ls ./
# !ls ../
# Out:
# /content
# total 984
# drwxr-xr-x 1 root root   4096 Aug 15 13:44 sample_data
# -rw-r--r-- 1 root root   2050 Aug 21 02:07 bird.jpg
# -rw-r--r-- 1 root root   5219 Aug 21 02:07 bear.jpg
# -rw-r--r-- 1 root root 989645 Aug 21 02:07 cat.jpg
# bear.jpg  bird.jpg  cat.jpg  sample_data
# bin	 dev   lib32  NGC-DL-CONTAINER-LICENSE	root  sys    var
# boot	 etc   lib64  opt			run   tmp
# content  home  media  proc			sbin  tools
# datalab  lib   mnt    python-apt		srv   usr

# %%
import matplotlib.pyplot as plt
# dir(plt)
cat = plt.imread('./cat.jpg')
cat.shape, cat.dtype
# Out:
# ((1480, 1480, 3), dtype('uint8'))

# %%
plt.imshow(cat)
plt.show()

# %%
import matplotlib.pyplot as plt
# dir(plt)
bear = plt.imread('./bear.jpg')
print(bear.shape, bear.dtype)
plt.imshow(bear)
plt.show()
# Out:
# (189, 267, 3) uint8

# %%
# !pip list

# %%
from skimage import color
color.rgb2gray?

# %%
from skimage import color
plt.imshow( color.rgb2gray(cat), cmap='gray' )
plt.show()

# %%
color.rgb2gray(cat).shape
# Out:
# (1480, 1480)
