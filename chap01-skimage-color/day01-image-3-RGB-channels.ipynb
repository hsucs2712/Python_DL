# %%
import matplotlib.pyplot as plt
cat = plt.imread('cat.jpg')
cat.shape
# Out:
# (1480, 1480, 3)

# %%
plt.imshow(cat)
plt.show()

# %%
cat_r = cat[:, :, 0] # Red
cat_g = cat[:, :, 1] # Green
cat_b = cat[:, :, 2] # Blue

# %%
plt.imshow(cat_b, cmap='gray') # <-- cat_r|g|b
plt.show()

# %%
cat2 = cat.copy()
#cat2[:, :, 0] = 0    # R
cat2[:, :, 1] = 0    # G
cat2[:, :, 2] = 0    # B
plt.imshow(cat2)
plt.show()
